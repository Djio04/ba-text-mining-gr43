# %% [markdown]
# # Lab6.4-Topic-classification-BERT

# %% [markdown]
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# In this notebook, we demonstrate how to fine-tune BERT for topic classification.
#
# We will use the [simpletransformers library](https://simpletransformers.ai/):
#  wrapper for the [huggingface transformers library](https://huggingface.co/) on PyTorch.

# %% [markdown]
# We are going to run the notebook on [colab](https://colab.research.google.com/?utm_source=scs-index), which has (limited) free access to GPUs.
#
# You need to enable GPUs for the notebook:
#
# * navigate to Edit → Notebook Settings
# * select GPU from the Hardware Accelerator drop-down

# %% [markdown]
# ### Install/import libraries

# %% [markdown]
# Install the simpletransformers library (restart your runtime after the installation)

# %%
# !pip install simpletransformers --upgrade
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.70.1-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: numpy in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from simpletransformers) (1.26.4)
# Collecting requests (from simpletransformers)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm>=4.47.0 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from simpletransformers) (4.67.1)
# Requirement already satisfied: regex in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from simpletransformers) (2024.11.6)
# Collecting transformers>=4.31.0 (from simpletransformers)
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Collecting datasets (from simpletransformers)
#   Downloading datasets-3.4.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scipy in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from simpletransformers) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from simpletransformers) (1.6.1)
# Collecting seqeval (from simpletransformers)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tensorboard (from simpletransformers)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorboardx (from simpletransformers)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from simpletransformers) (2.2.3)
# Collecting tokenizers (from simpletransformers)
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Downloading wandb-0.19.8-py3-none-win_amd64.whl.metadata (10 kB)
# Collecting streamlit (from simpletransformers)
#   Downloading streamlit-1.43.2-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting sentencepiece (from simpletransformers)
#   Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: colorama in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from tqdm>=4.47.0->simpletransformers) (0.4.6)
# Collecting filelock (from transformers>=4.31.0->simpletransformers)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.26.0 (from transformers>=4.31.0->simpletransformers)
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from transformers>=4.31.0->simpletransformers) (24.2)
# Collecting pyyaml>=5.1 (from transformers>=4.31.0->simpletransformers)
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.31.0->simpletransformers)
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: click!=8.0.0,>=7.1 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from wandb>=0.10.32->simpletransformers) (8.1.7)
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from wandb>=0.10.32->simpletransformers) (4.3.6)
# Collecting protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from wandb>=0.10.32->simpletransformers) (5.9.0)
# Collecting pydantic<3,>=2.6 (from wandb>=0.10.32->simpletransformers)
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading sentry_sdk-2.22.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Downloading setproctitle-1.3.5-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from wandb>=0.10.32->simpletransformers) (75.8.0)
# Collecting charset-normalizer<4,>=2 (from requests->simpletransformers)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests->simpletransformers)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->simpletransformers)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->simpletransformers)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyarrow>=15.0.0 (from datasets->simpletransformers)
#   Downloading pyarrow-19.0.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->simpletransformers)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->simpletransformers)
#   Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets->simpletransformers)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->simpletransformers)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets->simpletransformers)
#   Downloading aiohttp-3.11.13-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from pandas->simpletransformers) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from pandas->simpletransformers) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from pandas->simpletransformers) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from scikit-learn->simpletransformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from scikit-learn->simpletransformers) (3.5.0)
# Collecting altair<6,>=4.0 (from streamlit->simpletransformers)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->simpletransformers)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->simpletransformers)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pillow<12,>=7.1.0 (from streamlit->simpletransformers)
#   Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit->simpletransformers)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->simpletransformers)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from streamlit->simpletransformers) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit->simpletransformers)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->simpletransformers)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from streamlit->simpletransformers) (6.4.2)
# Collecting absl-py>=0.4 (from tensorboard->simpletransformers)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->simpletransformers)
#   Downloading grpcio-1.71.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting markdown>=2.6.8 (from tensorboard->simpletransformers)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: six>1.9 in c:\users\lisam\anaconda3\envs\textmining\lib\site-packages (from tensorboard->simpletransformers) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->simpletransformers)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->simpletransformers)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting jinja2 (from altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading narwhals-1.30.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets->simpletransformers)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->simpletransformers)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets->simpletransformers)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->simpletransformers)
#   Downloading frozenlist-1.5.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->simpletransformers)
#   Downloading multidict-6.1.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets->simpletransformers)
#   Downloading propcache-0.3.0-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets->simpletransformers)
#   Downloading yarl-1.18.3-cp312-cp312-win_amd64.whl.metadata (71 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.6->wandb>=0.10.32->simpletransformers)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3,>=2.6->wandb>=0.10.32->simpletransformers)
#   Using cached pydantic_core-2.27.2-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard->simpletransformers)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading rpds_py-0.23.1-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Downloading simpletransformers-0.70.1-py3-none-any.whl (316 kB)
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    -------------------------- ------------- 6.6/10.0 MB 30.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 31.0 MB/s eta 0:00:00
# Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 35.1 MB/s eta 0:00:00
# Downloading wandb-0.19.8-py3-none-win_amd64.whl (20.2 MB)
#    ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#    --------------- ------------------------ 7.6/20.2 MB 36.2 MB/s eta 0:00:01
#    ------------------------------- -------- 16.0/20.2 MB 38.7 MB/s eta 0:00:01
#    ---------------------------------------- 20.2/20.2 MB 35.4 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading datasets-3.4.0-py3-none-any.whl (487 kB)
# Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/992.0 kB ? eta -:--:--
#    --------------------------------------- 992.0/992.0 kB 22.8 MB/s eta 0:00:00
# Downloading streamlit-1.43.2-py2.py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------  9.7/9.7 MB 50.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 43.3 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 5.5/5.5 MB 37.2 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    --------------------------------------- 731.2/731.2 kB 31.3 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading aiohttp-3.11.13-cp312-cp312-win_amd64.whl (438 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading grpcio-1.71.0-cp312-cp312-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 4.3/4.3 MB 36.5 MB/s eta 0:00:00
# Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 18.9 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Downloading pyarrow-19.0.1-cp312-cp312-win_amd64.whl (25.3 MB)
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#    -------------- ------------------------- 9.2/25.3 MB 47.4 MB/s eta 0:00:01
#    -------------------------- ------------- 16.8/25.3 MB 40.6 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/25.3 MB 39.1 MB/s eta 0:00:01
#    ---------------------------------------- 25.3/25.3 MB 36.3 MB/s eta 0:00:00
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp312-cp312-win_amd64.whl (2.0 MB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 6.9/6.9 MB 35.5 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading sentry_sdk-2.22.0-py2.py3-none-any.whl (325 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading setproctitle-1.3.5-cp312-cp312-win_amd64.whl (12 kB)
# Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.5.0-cp312-cp312-win_amd64.whl (51 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Downloading multidict-6.1.0-cp312-cp312-win_amd64.whl (28 kB)
# Downloading narwhals-1.30.0-py3-none-any.whl (313 kB)
# Downloading propcache-0.3.0-cp312-cp312-win_amd64.whl (44 kB)
# Downloading yarl-1.18.3-cp312-cp312-win_amd64.whl (90 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.23.1-cp312-cp312-win_amd64.whl (237 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py): started
#   Building wheel for seqeval (setup.py): finished with status 'done'
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16247 sha256=808bcfd1ef62b0d105c61cfdc6f72a5aa22819432507d72bf9877277f860004a
#   Stored in directory: c:\users\lisam\appdata\local\pip\cache\wheels\5f\b8\73\0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: sentencepiece, xxhash, watchdog, urllib3, toml, tensorboard-data-server, tenacity, smmap, setproctitle, safetensors, rpds-py, pyyaml, pydantic-core, pyarrow, protobuf, propcache, pillow, narwhals, multidict, MarkupSafe, markdown, idna, grpcio, fsspec, frozenlist, filelock, docker-pycreds, dill, charset-normalizer, certifi, cachetools, blinker, attrs, annotated-types, aiohappyeyeballs, absl-py, yarl, werkzeug, tensorboardx, sentry-sdk, requests, referencing, pydantic, multiprocess, jinja2, gitdb, aiosignal, tensorboard, seqeval, pydeck, jsonschema-specifications, huggingface-hub, gitpython, aiohttp, wandb, tokenizers, jsonschema, transformers, datasets, altair, streamlit, simpletransformers
# Successfully installed MarkupSafe-3.0.2 absl-py-2.1.0 aiohappyeyeballs-2.6.1 aiohttp-3.11.13 aiosignal-1.3.2 altair-5.5.0 annotated-types-0.7.0 attrs-25.3.0 blinker-1.9.0 cachetools-5.5.2 certifi-2025.1.31 charset-normalizer-3.4.1 datasets-3.4.0 dill-0.3.8 docker-pycreds-0.4.0 filelock-3.18.0 frozenlist-1.5.0 fsspec-2024.12.0 gitdb-4.0.12 gitpython-3.1.44 grpcio-1.71.0 huggingface-hub-0.29.3 idna-3.10 jinja2-3.1.6 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 markdown-3.7 multidict-6.1.0 multiprocess-0.70.16 narwhals-1.30.0 pillow-11.1.0 propcache-0.3.0 protobuf-5.29.3 pyarrow-19.0.1 pydantic-2.10.6 pydantic-core-2.27.2 pydeck-0.9.1 pyyaml-6.0.2 referencing-0.36.2 requests-2.32.3 rpds-py-0.23.1 safetensors-0.5.3 sentencepiece-0.2.0 sentry-sdk-2.22.0 seqeval-1.2.2 setproctitle-1.3.5 simpletransformers-0.70.1 smmap-5.0.2 streamlit-1.43.2 tenacity-9.0.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorboardx-2.6.2.2 tokenizers-0.21.1 toml-0.10.2 transformers-4.49.0 urllib3-2.3.0 wandb-0.19.8 watchdog-6.0.0 werkzeug-3.1.3 xxhash-3.5.0 yarl-1.18.3

# %%
# Import libraries
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics import classification_report
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import matplotlib.pyplot as plt 
import seaborn as sn

# %% [markdown]
# Import [the 20 newsgroups text dataset](https://scikit-learn.org/0.19/datasets/twenty_newsgroups.html).
#
# The dataset contains around 18,000 newsgroups posts on 20 topics.

# %%
from sklearn.datasets import fetch_20newsgroups

# load only a sub-selection of the categories (4 in our case)
categories = ['alt.atheism', 'comp.graphics', 'sci.med', 'sci.space'] 

# remove the headers, footers and quotes (to avoid overfitting)
newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'), categories=categories, random_state=42)
newsgroups_test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'), categories=categories, random_state=42)

# %% [markdown]
# ### Data exploration

# %% [markdown]
# The target attribute is the integer index of the category:

# %%
from collections import Counter
Counter(newsgroups_train.target)
# Out:
# Counter({2: 594, 3: 593, 1: 584, 0: 480})

# %%
Counter(newsgroups_test.target)
# Out:
# Counter({2: 396, 3: 394, 1: 389, 0: 319})

# %% [markdown]
# Convert data to pandas dataframe

# %%
train = pd.DataFrame({'text': newsgroups_train.data, 'labels': newsgroups_train.target})

# %%
print(len(train))
train.head(5)
# Out:
# 2251
#                                                 text  labels
# 0  WHile we are on the subject of the shuttle sof...       3
# 1  There is a program called Graphic Workshop you...       1
# 2                                                          2
# 3  My girlfriend is in pain from kidney stones. S...       2
# 4  I think that's the correct spelling..\n\tI am ...       2

# %%
test = pd.DataFrame({'text': newsgroups_test.data, 'labels': newsgroups_test.target})

# %%
print(len(test))
test.head(5)
# Out:
# 1498
#                                                 text  labels
# 0  \nAnd guess who's here in your place.\n\nPleas...       1
# 1  Does anyone know if any of Currier and Ives et...       1
# 2  =FLAME ON\n=\n=Reading through the posts about...       2
# 3  \nBut in this case I said I hoped that BCCI wa...       0
# 4  \nIn the kind I have made I used a Lite sour c...       2

# %% [markdown]
# Use a subset (10%) of the training set as a validation set

# %%
from sklearn.model_selection import train_test_split

train, dev = train_test_split(train, test_size=0.1, random_state=0, 
                               stratify=train[['labels']])

# %%
print(len(train))
print("train:", train[['labels']].value_counts(sort=False))
train.head(3)
# Out:
# 2025
# train: labels
# 0         432
# 1         525
# 2         534
# 3         534
# Name: count, dtype: int64
#                                                    text  labels
# 559   I wonder how many atheists out there care to s...       0
# 2060  We are interested in purchasing a grayscale pr...       1
# 1206  Dear Binary Newsers,\n\nI am looking for Quick...       1

# %%
print(len(dev))
print("dev:", dev[['labels']].value_counts(sort=False))
dev.head(3)
# Out:
# 226
# dev: labels
# 0         48
# 1         59
# 2         60
# 3         59
# Name: count, dtype: int64
#                                                    text  labels
# 1570  I'd dump him.  Rude is rude and it seems he en...       2
# 1761  Hi Everyone ::\n\nI am  looking for  some soft...       1
# 455   A friend of mine has been diagnosed with Psori...       2

# %% [markdown]
# ## BERT

# %% [markdown]
# Define model's configuration

# %%
# Model configuration # https://simpletransformers.ai/docs/usage/#configuring-a-simple-transformers-model 
model_args = ClassificationArgs()

model_args.overwrite_output_dir=True # overwrite existing saved models in the same directory
model_args.evaluate_during_training=True # to perform evaluation while training the model
# (eval data should be passed to the training method)

model_args.num_train_epochs=10 # number of epochs
model_args.train_batch_size=32 # batch size
model_args.learning_rate=4e-6 # learning rate
model_args.max_seq_length=256 # maximum sequence length
# Note! Increasing max_seq_len may provide better performance, but training time will increase. 
# For educational purposes, we set max_seq_len to 256.

# Early stopping to combat overfitting: https://simpletransformers.ai/docs/tips-and-tricks/#using-early-stopping
model_args.use_early_stopping=True
model_args.early_stopping_delta=0.01 # "The improvement over best_eval_loss necessary to count as a better checkpoint"
model_args.early_stopping_metric='eval_loss'
model_args.early_stopping_metric_minimize=True
model_args.early_stopping_patience=2
model_args.evaluate_during_training_steps=32 # how often you want to run validation in terms of training steps (or batches)

# %% [markdown]
# With this configuration, the training will terminate if the eval_loss on the evaluation data does not improve upon the best eval_loss by at least 0.01 for 2 consecutive evaluations.
#
# An evaluation will occur once for every 32 training steps.

# %%
# Checking steps per epoch
steps_per_epoch = int(np.ceil(len(train) / float(model_args.train_batch_size)))
print('Each epoch will have {:,} steps.'.format(steps_per_epoch)) # 64 steps = validating 2 times per epoch
# Out:
# Each epoch will have 64 steps.

# %% [markdown]
# Load the pre-trained model: model_type = bert; model_name = [bert-base-cased](https://huggingface.co/bert-base-cased) (specifies the exact architecture and trained weights to use)

# %%
model = ClassificationModel('bert', 'bert-base-cased', num_labels=4, args=model_args, use_cuda=False) # CUDA is enabled
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(str(model.args).replace(',', '\n')) # model args
# Out:
# ClassificationArgs(adafactor_beta1=None
#  adafactor_clip_threshold=1.0
#  adafactor_decay_rate=-0.8
#  adafactor_eps=(1e-30
#  0.001)
#  adafactor_relative_step=True
#  adafactor_scale_parameter=True
#  adafactor_warmup_init=True
#  adam_betas=(0.9
#  0.999)
#  adam_epsilon=1e-08
#  best_model_dir='outputs/best_model'
#  cache_dir='cache_dir/'
#  config={}
#  cosine_schedule_num_cycles=0.5
#  custom_layer_parameters=[]
#  custom_parameter_groups=[]
#  dataloader_num_workers=0
#  do_lower_case=False
#  dynamic_quantize=False
#  early_stopping_consider_epochs=False
#  early_stopping_delta=0.01
#  early_stopping_metric='eval_loss'
#  early_stopping_metric_minimize=True
#  early_stopping_patience=2
#  encoding=None
#  eval_batch_size=100
#  evaluate_during_training=True
#  evaluate_during_training_silent=True
#  evaluate_during_training_steps=32
#  evaluate_during_training_verbose=False
#  evaluate_each_epoch=True
#  fp16=False
#  gradient_accumulation_steps=1
#  learning_rate=4e-06
#  local_rank=-1
#  logging_steps=50
#  loss_type=None
#  loss_args={}
#  manual_seed=None
#  max_grad_norm=1.0
#  max_seq_length=256
#  model_name='bert-base-cased'
#  model_type='bert'
#  multiprocessing_chunksize=-1
#  n_gpu=1
#  no_cache=False
#  no_save=False
#  not_saved_args=[]
#  num_train_epochs=10
#  optimizer='AdamW'
#  output_dir='outputs/'
#  overwrite_output_dir=True
#  polynomial_decay_schedule_lr_end=1e-07
#  polynomial_decay_schedule_power=1.0
#  process_count=18
#  quantized_model=False
#  reprocess_input_data=True
#  save_best_model=True
#  save_eval_checkpoints=True
#  save_model_every_epoch=True
#  save_optimizer_and_scheduler=True
#  save_steps=2000
#  scheduler='linear_schedule_with_warmup'
#  silent=False
#  skip_special_tokens=True
#  tensorboard_dir=None
#  thread_count=None
#  tokenizer_name='bert-base-cased'
#  tokenizer_type=None
#  train_batch_size=32
#  train_custom_parameters_only=False
#  trust_remote_code=False
#  use_cached_eval_features=False
#  use_early_stopping=True
#  use_hf_datasets=False
#  use_multiprocessing=True
#  use_multiprocessing_for_evaluation=True
#  wandb_kwargs={}
#  wandb_project=None
#  warmup_ratio=0.06
#  warmup_steps=0
#  weight_decay=0.0
#  model_class='ClassificationModel'
#  labels_list=[0
#  1
#  2
#  3]
#  labels_map={}
#  lazy_delimiter='\t'
#  lazy_labels_column=1
#  lazy_loading=False
#  lazy_loading_start_line=1
#  lazy_text_a_column=None
#  lazy_text_b_column=None
#  lazy_text_column=0
#  onnx=False
#  regression=False
#  sliding_window=False
#  special_tokens_list=[]
#  stride=0.8
#  tie_value=1)

# %% [markdown]
# Fine-tuning the model (takes a while)

# %%
_, history = model.train_model(train, eval_df=dev)
# Out:
# 5it [00:18,  3.68s/it]
# Epoch 1 of 10:   0%|          | 0/10 [00:00<?, ?it/s]
#
# 1it [00:16, 16.84s/it]
#
#
# 1it [00:16, 16.30s/it]
# Epochs 1/10. Running Loss:    1.3272: 100%|██████████| 64/64 [17:59<00:00, 16.86s/it]
# 1it [00:12, 12.43s/it]
# Epoch 2 of 10:  10%|█         | 1/10 [18:39<2:47:51, 1119.09s/it]
#
# 1it [00:13, 13.91s/it]
#
#
# 1it [00:22, 22.39s/it]
# Epochs 2/10. Running Loss:    1.0136: 100%|██████████| 64/64 [19:22<00:00, 18.16s/it]
# 1it [00:17, 17.51s/it]
# Epoch 3 of 10:  20%|██        | 2/10 [39:31<2:39:40, 1197.58s/it]
#
# 1it [00:22, 22.88s/it]
#
#
# 1it [00:16, 16.04s/it]
# Epochs 3/10. Running Loss:    0.5276: 100%|██████████| 64/64 [33:45<00:00, 31.66s/it]
# 1it [00:10, 10.97s/it]
# Epoch 4 of 10:  30%|███       | 3/10 [1:13:56<3:05:54, 1593.57s/it]
#
# 1it [00:15, 15.38s/it]
#
#
# 1it [00:16, 16.05s/it]
# Epochs 4/10. Running Loss:    0.2816: 100%|██████████| 64/64 [17:45<00:00, 16.65s/it]
# 1it [00:11, 11.45s/it]
# Epoch 5 of 10:  40%|████      | 4/10 [1:32:21<2:20:03, 1400.56s/it]
#
# 1it [00:21, 21.16s/it]
#
#
# 1it [00:15, 15.78s/it]
# Epochs 5/10. Running Loss:    0.4043: 100%|██████████| 64/64 [32:49<00:00, 30.77s/it]
# 1it [00:10, 10.36s/it]
# Epoch 6 of 10:  50%|█████     | 5/10 [2:05:48<2:14:56, 1619.39s/it]
#
# 1it [00:22, 22.03s/it]
#
#
# 1it [00:14, 14.65s/it]
# Epochs 6/10. Running Loss:    0.4732: 100%|██████████| 64/64 [27:32<00:00, 25.82s/it]
# 1it [00:11, 11.81s/it]
# Epoch 7 of 10:  60%|██████    | 6/10 [2:34:00<1:49:36, 1644.24s/it]
#
# 1it [00:23, 23.29s/it]
#
#
# 1it [00:20, 20.29s/it]
# Epochs 7/10. Running Loss:    0.6369: 100%|██████████| 64/64 [34:21<00:00, 32.21s/it]
# 1it [00:15, 15.88s/it]
# Epoch 8 of 10:  70%|███████   | 7/10 [3:09:47<1:30:25, 1808.58s/it]
#
# 1it [00:22, 22.39s/it]
# Epoch 8 of 10:  70%|███████   | 7/10 [3:30:13<1:30:05, 1801.95s/it]
# Epochs 8/10. Running Loss:    0.1781:  48%|████▊     | 31/64 [20:25<21:44, 39.54s/it]

# %%
# Training and evaluation loss
train_loss = history['train_loss']
eval_loss = history['eval_loss']
plt.plot(train_loss, label='Training loss')
plt.plot(eval_loss, label='Evaluation loss')
plt.title('Training and evaluation loss')
plt.legend()

# %% [markdown]
# * Loss measures the “goodness” of your model
#
# * The smaller the loss, the better the classifier is at modeling the relationship between the input data and the output targets
#
# * But you need to be careful not to overfit

# %% [markdown]
# In our case, we stopped training because eval_loss loss did not improve upon the best eval_loss by at least 0.01 for 2 consecutive evaluations.
#
# We can observe fluctuations in the training loss, but overall it is decreasing.
# We can have a smoother learning curve by varying hyperparameters, e.g., learning rate, batch size.

# %%
# Evaluate the model
result, model_outputs, wrong_predictions = model.eval_model(dev)
result
# Out:
# 1it [00:11, 11.19s/it]
# Running Evaluation: 100%|██████████| 3/3 [00:27<00:00,  9.09s/it]
# {'mcc': 0.8408073684571691, 'eval_loss': 0.39399387439092}

# %% [markdown]
# * mcc: [ Matthews correlation coefficient](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.matthews_corrcoef.html)
#
# * eval_loss: Cross Entropy Loss for dev

# %% [markdown]
# Make predictions with the model (predict the labels of the documents in the test set)

# %%
predicted, probabilities = model.predict(test.text.to_list())
test['predicted'] = predicted
# Out:
# 3it [00:10,  3.46s/it]
# 100%|██████████| 15/15 [02:53<00:00, 11.59s/it]

# %% [markdown]
# Test set predictions

# %%
test.head(5)
# Out:
#                                                 text  labels  predicted
# 0  \nAnd guess who's here in your place.\n\nPleas...       1          1
# 1  Does anyone know if any of Currier and Ives et...       1          1
# 2  =FLAME ON\n=\n=Reading through the posts about...       2          2
# 3  \nBut in this case I said I hoped that BCCI wa...       0          0
# 4  \nIn the kind I have made I used a Lite sour c...       2          2

# %% [markdown]
# Evaluate the model's performance on the test set

# %%
# Result (note: your result can be different due to randomness in operations)
print(classification_report(test['labels'], test['predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79       319
#            1       0.90      0.92      0.91       389
#            2       0.90      0.89      0.89       396
#            3       0.87      0.81      0.84       394
#
#     accuracy                           0.86      1498
#    macro avg       0.86      0.86      0.86      1498
# weighted avg       0.86      0.86      0.86      1498

# %% [markdown]
# ### End of this notebook.
