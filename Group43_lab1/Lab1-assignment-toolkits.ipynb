# %% [markdown]
# # Lab1-Assignment
#
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL
#
# This notebook describes the assignment for Lab 1 of the text mining course.
#
# **Points**: each exercise is prefixed with the number of points you can obtain for the exercise.
#
# We assume you have worked through the following notebooks:
# * **Lab1.1-introduction**
# * **Lab1.2-introduction-to-NLTK**
# * **Lab1.3-introduction-to-spaCy**
#
# In this assignment, you will process an English text (**Lab1-apple-samsung-example.txt**) with both NLTK and spaCy and discuss the similarities and differences.

# %% [markdown]
# ## Credits
# The notebooks in this block have been originally created by [Marten Postma](https://martenpostma.github.io). Adaptations were made by [Filip Ilievski](http://ilievski.nl).

# %% [markdown]
# ## Tip: how to read a file from disk
# Let's open the file **Lab1-apple-samsung-example.txt** from disk.

# %%
from pprint import pprint ### needed to print python data more elegantly

# %%
from pathlib import Path

# %%
cur_dir = Path().resolve() # this should provide you with the folder in which this notebook is placed
path_to_file = Path.joinpath(cur_dir, 'Lab1-apple-samsung-example.txt')
print(path_to_file)
print('does path exist? ->', Path.exists(path_to_file))
# Out:
# C:\Users\lisam\OneDrive\Year 3\Period 4\Text Mining\ba-text-mining-gr43\lab_sessions\lab1\Lab1-apple-samsung-example.txt
# does path exist? -> True

# %% [markdown]
# If the output from the code cell above states that **does path exist? -> False**, please check that the file **Lab1-apple-samsung-example.txt** is in the same directory as this notebook.

# %%
with open(path_to_file) as infile:
    text = infile.read()

print('number of characters', len(text))
# Out:
# number of characters 1139

# %% [markdown]
# ## [total points: 4] Exercise 1: NLTK
# In this exercise, we use NLTK to apply **Part-of-speech (POS) tagging**, **Named Entity Recognition (NER)**, and **Constituency parsing**. The following code snippet already performs sentence splitting and tokenization.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\lisam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import sent_tokenize
from nltk import word_tokenize

# %%
sentences_nltk = sent_tokenize(text)

# %%
tokens_per_sentence = []
for sentence_nltk in sentences_nltk:
    sent_tokens = word_tokenize(sentence_nltk)
    tokens_per_sentence.append(sent_tokens)

# %% [markdown]
# We will use lists to keep track of the output of the NLP tasks. We can hence inspect the output for each task using the index of the sentence.

# %%
sent_id = 1
print('SENTENCE', sentences_nltk[sent_id])
print('TOKENS', tokens_per_sentence[sent_id])
# Out:
# SENTENCE The six phones and tablets affected are the Galaxy S III, running the new Jelly Bean system, the Galaxy Tab 8.9 Wifi tablet, the Galaxy Tab 2 10.1, Galaxy Rugby Pro and Galaxy S III mini.
# TOKENS ['The', 'six', 'phones', 'and', 'tablets', 'affected', 'are', 'the', 'Galaxy', 'S', 'III', ',', 'running', 'the', 'new', 'Jelly', 'Bean', 'system', ',', 'the', 'Galaxy', 'Tab', '8.9', 'Wifi', 'tablet', ',', 'the', 'Galaxy', 'Tab', '2', '10.1', ',', 'Galaxy', 'Rugby', 'Pro', 'and', 'Galaxy', 'S', 'III', 'mini', '.']

# %% [markdown]
# ### [point: 1] Exercise 1a: Part-of-speech (POS) tagging
# Use `nltk.pos_tag` to perform part-of-speech tagging on each sentence.
#
# Use `print` to **show** the output in the notebook (and hence also in the exported PDF!).

# %%
pos_tags_per_sentence = []

for tokens in tokens_per_sentence:
    pos_tags = nltk.pos_tag(tokens)
    pos_tags_per_sentence.append(pos_tags)

# %%
pprint(pos_tags_per_sentence)
# Out:
# [[('https', 'NN'),
#   (':', ':'),
#   ('//www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html',
#    'JJ'),
#   ('Documents', 'NNS'),
#   ('filed', 'VBN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('San', 'NNP'),
#   ('Jose', 'NNP'),
#   ('federal', 'JJ'),
#   ('court', 'NN'),
#   ('in', 'IN'),
#   ('California', 'NNP'),
#   ('on', 'IN'),
#   ('November', 'NNP'),
#   ('23', 'CD'),
#   ('list', 'NN'),
#   ('six', 'CD'),
#   ('Samsung', 'NNP'),
#   ('products', 'NNS'),
#   ('running', 'VBG'),
#   ('the', 'DT'),
#   ('``', '``'),
#   ('Jelly', 'RB'),
#   ('Bean', 'NNP'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('``', '``'),
#   ('Ice', 'NNP'),
#   ('Cream', 'NNP'),
#   ('Sandwich', 'NNP'),
#   ("''", "''"),
#   ('operating', 'VBG'),
#   ('systems', 'NNS'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('Apple', 'NNP'),
#   ('claims', 'VBZ'),
#   ('infringe', 'VB'),
#   ('its', 'PRP$'),
#   ('patents', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('six', 'CD'),
#   ('phones', 'NNS'),
#   ('and', 'CC'),
#   ('tablets', 'NNS'),
#   ('affected', 'VBN'),
#   ('are', 'VBP'),
#   ('the', 'DT'),
#   ('Galaxy', 'NNP'),
#   ('S', 'NNP'),
#   ('III', 'NNP'),
#   (',', ','),
#   ('running', 'VBG'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('Jelly', 'NNP'),
#   ('Bean', 'NNP'),
#   ('system', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('Galaxy', 'NNP'),
#   ('Tab', 'NNP'),
#   ('8.9', 'CD'),
#   ('Wifi', 'NNP'),
#   ('tablet', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('Galaxy', 'NNP'),
#   ('Tab', 'NNP'),
#   ('2', 'CD'),
#   ('10.1', 'CD'),
#   (',', ','),
#   ('Galaxy', 'NNP'),
#   ('Rugby', 'NNP'),
#   ('Pro', 'NNP'),
#   ('and', 'CC'),
#   ('Galaxy', 'NNP'),
#   ('S', 'NNP'),
#   ('III', 'NNP'),
#   ('mini', 'NN'),
#   ('.', '.')],
#  [('Apple', 'NNP'),
#   ('stated', 'VBD'),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('“', 'NNP'),
#   ('acted', 'VBD'),
#   ('quickly', 'RB'),
#   ('and', 'CC'),
#   ('diligently', 'RB'),
#   ("''", "''"),
#   ('in', 'IN'),
#   ('order', 'NN'),
#   ('to', 'TO'),
#   ('``', '``'),
#   ('determine', 'VB'),
#   ('that', 'IN'),
#   ('these', 'DT'),
#   ('newly', 'RB'),
#   ('released', 'VBN'),
#   ('products', 'NNS'),
#   ('do', 'VBP'),
#   ('infringe', 'VB'),
#   ('many', 'JJ'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('claims', 'NNS'),
#   ('already', 'RB'),
#   ('asserted', 'VBN'),
#   ('by', 'IN'),
#   ('Apple', 'NNP'),
#   ('.', '.'),
#   ("''", "''")],
#  [('In', 'IN'),
#   ('August', 'NNP'),
#   (',', ','),
#   ('Samsung', 'NNP'),
#   ('lost', 'VBD'),
#   ('a', 'DT'),
#   ('US', 'NNP'),
#   ('patent', 'NN'),
#   ('case', 'NN'),
#   ('to', 'TO'),
#   ('Apple', 'NNP'),
#   ('and', 'CC'),
#   ('was', 'VBD'),
#   ('ordered', 'VBN'),
#   ('to', 'TO'),
#   ('pay', 'VB'),
#   ('its', 'PRP$'),
#   ('rival', 'JJ'),
#   ('$', '$'),
#   ('1.05bn', 'CD'),
#   ('(', '('),
#   ('£0.66bn', 'NN'),
#   (')', ')'),
#   ('in', 'IN'),
#   ('damages', 'NNS'),
#   ('for', 'IN'),
#   ('copying', 'VBG'),
#   ('features', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('iPad', 'NN'),
#   ('and', 'CC'),
#   ('iPhone', 'NN'),
#   ('in', 'IN'),
#   ('its', 'PRP$'),
#   ('Galaxy', 'NNP'),
#   ('range', 'NN'),
#   ('of', 'IN'),
#   ('devices', 'NNS'),
#   ('.', '.')],
#  [('Samsung', 'NNP'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ("'s", 'POS'),
#   ('top', 'JJ'),
#   ('mobile', 'NN'),
#   ('phone', 'NN'),
#   ('maker', 'NN'),
#   (',', ','),
#   ('is', 'VBZ'),
#   ('appealing', 'VBG'),
#   ('the', 'DT'),
#   ('ruling', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('similar', 'JJ'),
#   ('case', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('UK', 'NNP'),
#   ('found', 'VBD'),
#   ('in', 'IN'),
#   ('Samsung', 'NNP'),
#   ("'s", 'POS'),
#   ('favour', 'NN'),
#   ('and', 'CC'),
#   ('ordered', 'VBD'),
#   ('Apple', 'NNP'),
#   ('to', 'TO'),
#   ('publish', 'VB'),
#   ('an', 'DT'),
#   ('apology', 'NN'),
#   ('making', 'VBG'),
#   ('clear', 'JJ'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('South', 'JJ'),
#   ('Korean', 'JJ'),
#   ('firm', 'NN'),
#   ('had', 'VBD'),
#   ('not', 'RB'),
#   ('copied', 'VBN'),
#   ('its', 'PRP$'),
#   ('iPad', 'NN'),
#   ('when', 'WRB'),
#   ('designing', 'VBG'),
#   ('its', 'PRP$'),
#   ('own', 'JJ'),
#   ('devices', 'NNS'),
#   ('.', '.')]]

# %% [markdown]
# ### [point: 1] Exercise 1b: Named Entity Recognition (NER)
# Use `nltk.chunk.ne_chunk` to perform Named Entity Recognition (NER) on each sentence.
#
# Use `print` to **show** the output in the notebook (and hence also in the exported PDF!).

# %%
ner_tags_per_sentence = []

for tokens in tokens_per_sentence:
    ner_tags = nltk.ne_chunk(nltk.pos_tag(tokens))
    ner_tags_per_sentence.append(ner_tags)

# %%
for sentence, ner_tags in zip(sentences, ner_tags_per_sentence):
    print("Original sentence:", sentence, "\n")
    print(ner_tags, "\n")
# Out:
# Original sentence: https://www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html
#
# Documents filed to the San Jose federal court in California on November 23 list six Samsung products running the "Jelly Bean" and "Ice Cream Sandwich" operating systems, which Apple claims infringe its patents.
#
# (S
#   https/NN
#   :/:
#   //www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html/JJ
#   Documents/NNS
#   filed/VBN
#   to/TO
#   the/DT
#   (ORGANIZATION San/NNP Jose/NNP)
#   federal/JJ
#   court/NN
#   in/IN
#   (GPE California/NNP)
#   on/IN
#   November/NNP
#   23/CD
#   list/NN
#   six/CD
#   (ORGANIZATION Samsung/NNP)
#   products/NNS
#   running/VBG
#   the/DT
#   ``/``
#   Jelly/RB
#   (GPE Bean/NNP)
#   ''/''
#   and/CC
#   ``/``
#   Ice/NNP
#   Cream/NNP
#   Sandwich/NNP
#   ''/''
#   operating/VBG
#   systems/NNS
#   ,/,
#   which/WDT
#   (PERSON Apple/NNP)
#   claims/VBZ
#   infringe/VB
#   its/PRP$
#   patents/NNS
#   ./.)
#
# Original sentence: The six phones and tablets affected are the Galaxy S III, running the new Jelly Bean system, the Galaxy Tab 8.9 Wifi tablet, the Galaxy Tab 2 10.1, Galaxy Rugby Pro and Galaxy S III mini.
#
# (S
#   The/DT
#   six/CD
#   phones/NNS
#   and/CC
#   tablets/NNS
#   affected/VBN
#   are/VBP
#   the/DT
#   (ORGANIZATION Galaxy/NNP)
#   S/NNP
#   III/NNP
#   ,/,
#   running/VBG
#   the/DT
#   new/JJ
#   (PERSON Jelly/NNP Bean/NNP)
#   system/NN
#   ,/,
#   the/DT
#   (ORGANIZATION Galaxy/NNP)
#   Tab/NNP
#   8.9/CD
#   Wifi/NNP
#   tablet/NN
#   ,/,
#   the/DT
#   (ORGANIZATION Galaxy/NNP)
#   Tab/NNP
#   2/CD
#   10.1/CD
#   ,/,
#   (PERSON Galaxy/NNP Rugby/NNP Pro/NNP)
#   and/CC
#   (PERSON Galaxy/NNP S/NNP)
#   III/NNP
#   mini/NN
#   ./.)
#
# Original sentence: Apple stated it had “acted quickly and diligently" in order to "determine that these newly released products do infringe many of the same claims already asserted by Apple."
#
# (S
#   (PERSON Apple/NNP)
#   stated/VBD
#   it/PRP
#   had/VBD
#   “/NNP
#   acted/VBD
#   quickly/RB
#   and/CC
#   diligently/RB
#   ''/''
#   in/IN
#   order/NN
#   to/TO
#   ``/``
#   determine/VB
#   that/IN
#   these/DT
#   newly/RB
#   released/VBN
#   products/NNS
#   do/VBP
#   infringe/VB
#   many/JJ
#   of/IN
#   the/DT
#   same/JJ
#   claims/NNS
#   already/RB
#   asserted/VBN
#   by/IN
#   (PERSON Apple/NNP)
#   ./.
#   ''/'')
#
# Original sentence: In August, Samsung lost a US patent case to Apple and was ordered to pay its rival $1.05bn (£0.66bn) in damages for copying features of the iPad and iPhone in its Galaxy range of devices.
#
# (S
#   In/IN
#   (GPE August/NNP)
#   ,/,
#   (PERSON Samsung/NNP)
#   lost/VBD
#   a/DT
#   (GSP US/NNP)
#   patent/NN
#   case/NN
#   to/TO
#   (GPE Apple/NNP)
#   and/CC
#   was/VBD
#   ordered/VBN
#   to/TO
#   pay/VB
#   its/PRP$
#   rival/JJ
#   $/$
#   1.05bn/CD
#   (/(
#   £0.66bn/NN
#   )/)
#   in/IN
#   damages/NNS
#   for/IN
#   copying/VBG
#   features/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION iPad/NN)
#   and/CC
#   (ORGANIZATION iPhone/NN)
#   in/IN
#   its/PRP$
#   (GPE Galaxy/NNP)
#   range/NN
#   of/IN
#   devices/NNS
#   ./.)
#
# Original sentence: Samsung, which is the world's top mobile phone maker, is appealing the ruling.
#
# (S
#   (GPE Samsung/NNP)
#   ,/,
#   which/WDT
#   is/VBZ
#   the/DT
#   world/NN
#   's/POS
#   top/JJ
#   mobile/NN
#   phone/NN
#   maker/NN
#   ,/,
#   is/VBZ
#   appealing/VBG
#   the/DT
#   ruling/NN
#   ./.)
#
# Original sentence: A similar case in the UK found in Samsung's favour and ordered Apple to publish an apology making clear that the South Korean firm had not copied its iPad when designing its own devices.
#
# (S
#   A/DT
#   similar/JJ
#   case/NN
#   in/IN
#   the/DT
#   (ORGANIZATION UK/NNP)
#   found/VBD
#   in/IN
#   (GPE Samsung/NNP)
#   's/POS
#   favour/NN
#   and/CC
#   ordered/VBD
#   (PERSON Apple/NNP)
#   to/TO
#   publish/VB
#   an/DT
#   apology/NN
#   making/VBG
#   clear/JJ
#   that/IN
#   the/DT
#   (LOCATION South/JJ Korean/JJ)
#   firm/NN
#   had/VBD
#   not/RB
#   copied/VBN
#   its/PRP$
#   iPad/NN
#   when/WRB
#   designing/VBG
#   its/PRP$
#   own/JJ
#   devices/NNS
#   ./.)

# %% [markdown]
# ### [points: 2] Exercise 1c: Constituency parsing
# Use the `nltk.RegexpParser` to perform constituency parsing on each sentence.
#
# Use `print` to **show** the output in the notebook (and hence also in the exported PDF!).

# %%
constituent_parser = nltk.RegexpParser('''
NP: {<DT>? <JJ>* <NN>*} # NP
P: {<IN>}           # Preposition
V: {<V.*>}          # Verb
PP: {<P> <NP>}      # PP -> P NPa
VP: {<V> <NP|PP>*}  # VP -> V (NP|PP)*
''')

# %%
constituency_output_per_sentence = []

for tokens in tokens_per_sentence:
    tagged = nltk.pos_tag(tokens)
    constituent_structure = constituent_parser.parse(tagged)
    constituency_output_per_sentence.append(constituent_structure)

# %%
for sentence, constituent_structure in zip(sentences, constituency_output_per_sentence):
    print("Original sentence:", sentence, "\n")
    print(constituent_structure, "\n")
# Out:
# Original sentence: https://www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html
#
# Documents filed to the San Jose federal court in California on November 23 list six Samsung products running the "Jelly Bean" and "Ice Cream Sandwich" operating systems, which Apple claims infringe its patents.
#
# (S
#   (NP https/NN)
#   :/:
#   (NP
#     //www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html/JJ)
#   Documents/NNS
#   (VP (V filed/VBN))
#   to/TO
#   (NP the/DT)
#   San/NNP
#   Jose/NNP
#   (NP federal/JJ court/NN)
#   (P in/IN)
#   California/NNP
#   (P on/IN)
#   November/NNP
#   23/CD
#   (NP list/NN)
#   six/CD
#   Samsung/NNP
#   products/NNS
#   (VP (V running/VBG) (NP the/DT))
#   ``/``
#   Jelly/RB
#   Bean/NNP
#   ''/''
#   and/CC
#   ``/``
#   Ice/NNP
#   Cream/NNP
#   Sandwich/NNP
#   ''/''
#   (VP (V operating/VBG))
#   systems/NNS
#   ,/,
#   which/WDT
#   Apple/NNP
#   (VP (V claims/VBZ))
#   (VP (V infringe/VB))
#   its/PRP$
#   patents/NNS
#   ./.)
#
# Original sentence: The six phones and tablets affected are the Galaxy S III, running the new Jelly Bean system, the Galaxy Tab 8.9 Wifi tablet, the Galaxy Tab 2 10.1, Galaxy Rugby Pro and Galaxy S III mini.
#
# (S
#   (NP The/DT)
#   six/CD
#   phones/NNS
#   and/CC
#   tablets/NNS
#   (VP (V affected/VBN))
#   (VP (V are/VBP) (NP the/DT))
#   Galaxy/NNP
#   S/NNP
#   III/NNP
#   ,/,
#   (VP (V running/VBG) (NP the/DT new/JJ))
#   Jelly/NNP
#   Bean/NNP
#   (NP system/NN)
#   ,/,
#   (NP the/DT)
#   Galaxy/NNP
#   Tab/NNP
#   8.9/CD
#   Wifi/NNP
#   (NP tablet/NN)
#   ,/,
#   (NP the/DT)
#   Galaxy/NNP
#   Tab/NNP
#   2/CD
#   10.1/CD
#   ,/,
#   Galaxy/NNP
#   Rugby/NNP
#   Pro/NNP
#   and/CC
#   Galaxy/NNP
#   S/NNP
#   III/NNP
#   (NP mini/NN)
#   ./.)
#
# Original sentence: Apple stated it had “acted quickly and diligently" in order to "determine that these newly released products do infringe many of the same claims already asserted by Apple."
#
# (S
#   Apple/NNP
#   (VP (V stated/VBD))
#   it/PRP
#   (VP (V had/VBD))
#   “/NNP
#   (VP (V acted/VBD))
#   quickly/RB
#   and/CC
#   diligently/RB
#   ''/''
#   (PP (P in/IN) (NP order/NN))
#   to/TO
#   ``/``
#   (VP (V determine/VB) (PP (P that/IN) (NP these/DT)))
#   newly/RB
#   (VP (V released/VBN))
#   products/NNS
#   (VP (V do/VBP))
#   (VP
#     (V infringe/VB)
#     (NP many/JJ)
#     (PP (P of/IN) (NP the/DT same/JJ)))
#   claims/NNS
#   already/RB
#   (VP (V asserted/VBN))
#   (P by/IN)
#   Apple/NNP
#   ./.
#   ''/'')
#
# Original sentence: In August, Samsung lost a US patent case to Apple and was ordered to pay its rival $1.05bn (£0.66bn) in damages for copying features of the iPad and iPhone in its Galaxy range of devices.
#
# (S
#   (P In/IN)
#   August/NNP
#   ,/,
#   Samsung/NNP
#   (VP (V lost/VBD) (NP a/DT))
#   US/NNP
#   (NP patent/NN case/NN)
#   to/TO
#   Apple/NNP
#   and/CC
#   (VP (V was/VBD))
#   (VP (V ordered/VBN))
#   to/TO
#   (VP (V pay/VB))
#   its/PRP$
#   (NP rival/JJ)
#   $/$
#   1.05bn/CD
#   (/(
#   (NP £0.66bn/NN)
#   )/)
#   (P in/IN)
#   damages/NNS
#   (P for/IN)
#   (VP (V copying/VBG))
#   features/NNS
#   (PP (P of/IN) (NP the/DT iPad/NN))
#   and/CC
#   (NP iPhone/NN)
#   (P in/IN)
#   its/PRP$
#   Galaxy/NNP
#   (NP range/NN)
#   (P of/IN)
#   devices/NNS
#   ./.)
#
# Original sentence: Samsung, which is the world's top mobile phone maker, is appealing the ruling.
#
# (S
#   Samsung/NNP
#   ,/,
#   which/WDT
#   (VP (V is/VBZ) (NP the/DT world/NN))
#   's/POS
#   (NP top/JJ mobile/NN phone/NN maker/NN)
#   ,/,
#   (VP (V is/VBZ))
#   (VP (V appealing/VBG) (NP the/DT ruling/NN))
#   ./.)
#
# Original sentence: A similar case in the UK found in Samsung's favour and ordered Apple to publish an apology making clear that the South Korean firm had not copied its iPad when designing its own devices.
#
# (S
#   (NP A/DT similar/JJ case/NN)
#   (PP (P in/IN) (NP the/DT))
#   UK/NNP
#   (VP (V found/VBD))
#   (P in/IN)
#   Samsung/NNP
#   's/POS
#   (NP favour/NN)
#   and/CC
#   (VP (V ordered/VBD))
#   Apple/NNP
#   to/TO
#   (VP (V publish/VB) (NP an/DT apology/NN))
#   (VP
#     (V making/VBG)
#     (NP clear/JJ)
#     (PP (P that/IN) (NP the/DT South/JJ Korean/JJ firm/NN)))
#   (VP (V had/VBD))
#   not/RB
#   (VP (V copied/VBN))
#   its/PRP$
#   (NP iPad/NN)
#   when/WRB
#   (VP (V designing/VBG))
#   its/PRP$
#   (NP own/JJ)
#   devices/NNS
#   ./.)

# %% [markdown]
# Augment the RegexpParser so that it also detects Named Entity Phrases (NEP), e.g., that it detects *Galaxy S III* and *Ice Cream Sandwich*

# %%
constituent_parser_v2 = nltk.RegexpParser('''
NP: {<DT>? <JJ>* <NN>*} # NP
P: {<IN>}           # Preposition
V: {<V.*>}          # Verb
PP: {<P> <NP>}      # PP -> P NP
VP: {<V> <NP|PP>*}  # VP -> V (NP|PP)*
NEP: {<NNP>+}       # Named Entity Phrase (NEP) - sequence of proper nouns (NNP)
''')

# %%
constituency_v2_output_per_sentence = []

for tokens in tokens_per_sentence:
    tagged = nltk.pos_tag(tokens)
    constituent_structure = constituent_parser_v2.parse(tagged)
    constituency_v2_output_per_sentence.append(constituent_structure)

# %%
for sentence, constituent_structure in zip(sentences, constituency_v2_output_per_sentence):
    print("Original sentence:", sentence, "\n")
    print(constituent_structure, "\n")
# Out:
# Original sentence: https://www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html
#
# Documents filed to the San Jose federal court in California on November 23 list six Samsung products running the "Jelly Bean" and "Ice Cream Sandwich" operating systems, which Apple claims infringe its patents.
#
# (S
#   (NP https/NN)
#   :/:
#   (NP
#     //www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html/JJ)
#   Documents/NNS
#   (VP (V filed/VBN))
#   to/TO
#   (NP the/DT)
#   (NEP San/NNP Jose/NNP)
#   (NP federal/JJ court/NN)
#   (P in/IN)
#   (NEP California/NNP)
#   (P on/IN)
#   (NEP November/NNP)
#   23/CD
#   (NP list/NN)
#   six/CD
#   (NEP Samsung/NNP)
#   products/NNS
#   (VP (V running/VBG) (NP the/DT))
#   ``/``
#   Jelly/RB
#   (NEP Bean/NNP)
#   ''/''
#   and/CC
#   ``/``
#   (NEP Ice/NNP Cream/NNP Sandwich/NNP)
#   ''/''
#   (VP (V operating/VBG))
#   systems/NNS
#   ,/,
#   which/WDT
#   (NEP Apple/NNP)
#   (VP (V claims/VBZ))
#   (VP (V infringe/VB))
#   its/PRP$
#   patents/NNS
#   ./.)
#
# Original sentence: The six phones and tablets affected are the Galaxy S III, running the new Jelly Bean system, the Galaxy Tab 8.9 Wifi tablet, the Galaxy Tab 2 10.1, Galaxy Rugby Pro and Galaxy S III mini.
#
# (S
#   (NP The/DT)
#   six/CD
#   phones/NNS
#   and/CC
#   tablets/NNS
#   (VP (V affected/VBN))
#   (VP (V are/VBP) (NP the/DT))
#   (NEP Galaxy/NNP S/NNP III/NNP)
#   ,/,
#   (VP (V running/VBG) (NP the/DT new/JJ))
#   (NEP Jelly/NNP Bean/NNP)
#   (NP system/NN)
#   ,/,
#   (NP the/DT)
#   (NEP Galaxy/NNP Tab/NNP)
#   8.9/CD
#   (NEP Wifi/NNP)
#   (NP tablet/NN)
#   ,/,
#   (NP the/DT)
#   (NEP Galaxy/NNP Tab/NNP)
#   2/CD
#   10.1/CD
#   ,/,
#   (NEP Galaxy/NNP Rugby/NNP Pro/NNP)
#   and/CC
#   (NEP Galaxy/NNP S/NNP III/NNP)
#   (NP mini/NN)
#   ./.)
#
# Original sentence: Apple stated it had “acted quickly and diligently" in order to "determine that these newly released products do infringe many of the same claims already asserted by Apple."
#
# (S
#   (NEP Apple/NNP)
#   (VP (V stated/VBD))
#   it/PRP
#   (VP (V had/VBD))
#   (NEP “/NNP)
#   (VP (V acted/VBD))
#   quickly/RB
#   and/CC
#   diligently/RB
#   ''/''
#   (PP (P in/IN) (NP order/NN))
#   to/TO
#   ``/``
#   (VP (V determine/VB) (PP (P that/IN) (NP these/DT)))
#   newly/RB
#   (VP (V released/VBN))
#   products/NNS
#   (VP (V do/VBP))
#   (VP
#     (V infringe/VB)
#     (NP many/JJ)
#     (PP (P of/IN) (NP the/DT same/JJ)))
#   claims/NNS
#   already/RB
#   (VP (V asserted/VBN))
#   (P by/IN)
#   (NEP Apple/NNP)
#   ./.
#   ''/'')
#
# Original sentence: In August, Samsung lost a US patent case to Apple and was ordered to pay its rival $1.05bn (£0.66bn) in damages for copying features of the iPad and iPhone in its Galaxy range of devices.
#
# (S
#   (P In/IN)
#   (NEP August/NNP)
#   ,/,
#   (NEP Samsung/NNP)
#   (VP (V lost/VBD) (NP a/DT))
#   (NEP US/NNP)
#   (NP patent/NN case/NN)
#   to/TO
#   (NEP Apple/NNP)
#   and/CC
#   (VP (V was/VBD))
#   (VP (V ordered/VBN))
#   to/TO
#   (VP (V pay/VB))
#   its/PRP$
#   (NP rival/JJ)
#   $/$
#   1.05bn/CD
#   (/(
#   (NP £0.66bn/NN)
#   )/)
#   (P in/IN)
#   damages/NNS
#   (P for/IN)
#   (VP (V copying/VBG))
#   features/NNS
#   (PP (P of/IN) (NP the/DT iPad/NN))
#   and/CC
#   (NP iPhone/NN)
#   (P in/IN)
#   its/PRP$
#   (NEP Galaxy/NNP)
#   (NP range/NN)
#   (P of/IN)
#   devices/NNS
#   ./.)
#
# Original sentence: Samsung, which is the world's top mobile phone maker, is appealing the ruling.
#
# (S
#   (NEP Samsung/NNP)
#   ,/,
#   which/WDT
#   (VP (V is/VBZ) (NP the/DT world/NN))
#   's/POS
#   (NP top/JJ mobile/NN phone/NN maker/NN)
#   ,/,
#   (VP (V is/VBZ))
#   (VP (V appealing/VBG) (NP the/DT ruling/NN))
#   ./.)
#
# Original sentence: A similar case in the UK found in Samsung's favour and ordered Apple to publish an apology making clear that the South Korean firm had not copied its iPad when designing its own devices.
#
# (S
#   (NP A/DT similar/JJ case/NN)
#   (PP (P in/IN) (NP the/DT))
#   (NEP UK/NNP)
#   (VP (V found/VBD))
#   (P in/IN)
#   (NEP Samsung/NNP)
#   's/POS
#   (NP favour/NN)
#   and/CC
#   (VP (V ordered/VBD))
#   (NEP Apple/NNP)
#   to/TO
#   (VP (V publish/VB) (NP an/DT apology/NN))
#   (VP
#     (V making/VBG)
#     (NP clear/JJ)
#     (PP (P that/IN) (NP the/DT South/JJ Korean/JJ firm/NN)))
#   (VP (V had/VBD))
#   not/RB
#   (VP (V copied/VBN))
#   its/PRP$
#   (NP iPad/NN)
#   when/WRB
#   (VP (V designing/VBG))
#   its/PRP$
#   (NP own/JJ)
#   devices/NNS
#   ./.)

# %% [markdown]
# ## [total points: 1] Exercise 2: spaCy
# Use Spacy to process the same text as you analyzed with NLTK.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

sents = list(doc.sents)

for i, sent in enumerate(sents):
    print(f"Original Sentence {i+1}: {sent.text} \n------------\n")

    print()
    print("Tokens and their POS tags (tag_):")
    for token in sent:
        print(f"{token.text}: {token.tag_} ({token.pos_})")

    print()
    print("Named Entities, Phrases, and Concepts:")
    for ent in sent.ents:
        print(f"{ent.text}: {ent.label_}")

    print("\n")
# Out:
# Original Sentence 1: https://www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html
#
# Documents filed to the San Jose federal court in California on November 23 list six Samsung products running the "Jelly Bean" and "Ice Cream Sandwich" operating systems, which Apple claims infringe its patents.
#
# ------------
#
#
# Tokens and their POS tags (tag_):
# https://www.telegraph.co.uk/technology/apple/9702716/Apple-Samsung-lawsuit-six-more-products-under-scrutiny.html: NNP (PROPN)
#
#
# : _SP (SPACE)
# Documents: NNPS (PROPN)
# filed: VBD (VERB)
# to: IN (ADP)
# the: DT (DET)
# San: NNP (PROPN)
# Jose: NNP (PROPN)
# federal: JJ (ADJ)
# court: NN (NOUN)
# in: IN (ADP)
# California: NNP (PROPN)
# on: IN (ADP)
# November: NNP (PROPN)
# 23: CD (NUM)
# list: NN (NOUN)
# six: CD (NUM)
# Samsung: NNP (PROPN)
# products: NNS (NOUN)
# running: VBG (VERB)
# the: DT (DET)
# ": `` (PUNCT)
# Jelly: NNP (PROPN)
# Bean: NNP (PROPN)
# ": '' (PUNCT)
# and: CC (CCONJ)
# ": `` (PUNCT)
# Ice: NNP (PROPN)
# Cream: NNP (PROPN)
# Sandwich: NNP (PROPN)
# ": '' (PUNCT)
# operating: NN (NOUN)
# systems: NNS (NOUN)
# ,: , (PUNCT)
# which: WDT (PRON)
# Apple: NNP (PROPN)
# claims: VBZ (VERB)
# infringe: VBP (VERB)
# its: PRP$ (PRON)
# patents: NNS (NOUN)
# .: . (PUNCT)
#
# : _SP (SPACE)
#
# Named Entities, Phrases, and Concepts:
# San Jose: GPE
# California: GPE
# November 23: DATE
# six: CARDINAL
# Samsung: ORG
# Jelly Bean: WORK_OF_ART
# Apple: ORG
#
#
# Original Sentence 2: The six phones and tablets affected are the Galaxy S III, running the new Jelly Bean system, the Galaxy Tab 8.9 Wifi tablet, the Galaxy Tab 2 10.1, Galaxy Rugby Pro and Galaxy S III mini.
#
# ------------
#
#
# Tokens and their POS tags (tag_):
# The: DT (DET)
# six: CD (NUM)
# phones: NNS (NOUN)
# and: CC (CCONJ)
# tablets: NNS (NOUN)
# affected: VBN (VERB)
# are: VBP (AUX)
# the: DT (DET)
# Galaxy: NNP (PROPN)
# S: NNP (PROPN)
# III: NNP (PROPN)
# ,: , (PUNCT)
# running: VBG (VERB)
# the: DT (DET)
# new: JJ (ADJ)
# Jelly: NNP (PROPN)
# Bean: NNP (PROPN)
# system: NN (NOUN)
# ,: , (PUNCT)
# the: DT (DET)
# Galaxy: NNP (PROPN)
# Tab: NNP (PROPN)
# 8.9: CD (NUM)
# Wifi: NNP (PROPN)
# tablet: NN (NOUN)
# ,: , (PUNCT)
# the: DT (DET)
# Galaxy: NNP (PROPN)
# Tab: NNP (PROPN)
# 2: CD (NUM)
# 10.1: CD (NUM)
# ,: , (PUNCT)
# Galaxy: NNP (PROPN)
# Rugby: NNP (PROPN)
# Pro: NNP (PROPN)
# and: CC (CCONJ)
# Galaxy: NNP (PROPN)
# S: NNP (PROPN)
# III: NNP (PROPN)
# mini: NN (NOUN)
# .: . (PUNCT)
#
# : _SP (SPACE)
#
# Named Entities, Phrases, and Concepts:
# six: CARDINAL
# the Galaxy S III: PERSON
# Jelly Bean: ORG
# Galaxy Tab 8.9 Wifi: PERSON
# Galaxy Tab 2 10.1: PERSON
#
#
# Original Sentence 3: Apple stated it had “acted quickly and diligently" in order to "determine that these newly released products do infringe many of the same claims already asserted by Apple.
# ------------
#
#
# Tokens and their POS tags (tag_):
# Apple: NNP (PROPN)
# stated: VBD (VERB)
# it: PRP (PRON)
# had: VBD (AUX)
# “: `` (PUNCT)
# acted: VBN (VERB)
# quickly: RB (ADV)
# and: CC (CCONJ)
# diligently: RB (ADV)
# ": '' (PUNCT)
# in: IN (ADP)
# order: NN (NOUN)
# to: TO (PART)
# ": `` (PUNCT)
# determine: VB (VERB)
# that: IN (SCONJ)
# these: DT (DET)
# newly: RB (ADV)
# released: VBN (VERB)
# products: NNS (NOUN)
# do: VBP (AUX)
# infringe: VB (VERB)
# many: JJ (ADJ)
# of: IN (ADP)
# the: DT (DET)
# same: JJ (ADJ)
# claims: NNS (NOUN)
# already: RB (ADV)
# asserted: VBN (VERB)
# by: IN (ADP)
# Apple: NNP (PROPN)
# .: . (PUNCT)
#
# Named Entities, Phrases, and Concepts:
# Apple: ORG
# Apple: ORG
#
#
# Original Sentence 4: "
# In August, Samsung lost a US patent case to Apple and was ordered to pay its rival $1.05bn (£0.66bn) in damages for copying features of the iPad and iPhone in its Galaxy range of devices.
# ------------
#
#
# Tokens and their POS tags (tag_):
# ": '' (PUNCT)
#
# : _SP (SPACE)
# In: IN (ADP)
# August: NNP (PROPN)
# ,: , (PUNCT)
# Samsung: NNP (PROPN)
# lost: VBD (VERB)
# a: DT (DET)
# US: NNP (PROPN)
# patent: NN (NOUN)
# case: NN (NOUN)
# to: IN (ADP)
# Apple: NNP (PROPN)
# and: CC (CCONJ)
# was: VBD (AUX)
# ordered: VBN (VERB)
# to: TO (PART)
# pay: VB (VERB)
# its: PRP$ (PRON)
# rival: JJ (ADJ)
# $: $ (SYM)
# 1.05bn: CD (NUM)
# (: -LRB- (PUNCT)
# £: $ (SYM)
# 0.66bn: CD (NUM)
# ): -RRB- (PUNCT)
# in: IN (ADP)
# damages: NNS (NOUN)
# for: IN (ADP)
# copying: VBG (VERB)
# features: NNS (NOUN)
# of: IN (ADP)
# the: DT (DET)
# iPad: NNP (PROPN)
# and: CC (CCONJ)
# iPhone: NNP (PROPN)
# in: IN (ADP)
# its: PRP$ (PRON)
# Galaxy: NNP (PROPN)
# range: NN (NOUN)
# of: IN (ADP)
# devices: NNS (NOUN)
# .: . (PUNCT)
#
# Named Entities, Phrases, and Concepts:
# August: DATE
# Samsung: ORG
# US: GPE
# Apple: ORG
# 1.05bn: MONEY
# 0.66bn: MONEY
# iPad: ORG
# iPhone: ORG
#
#
# Original Sentence 5: Samsung, which is the world's top mobile phone maker, is appealing the ruling.
#
# ------------
#
#
# Tokens and their POS tags (tag_):
# Samsung: NNP (PROPN)
# ,: , (PUNCT)
# which: WDT (PRON)
# is: VBZ (AUX)
# the: DT (DET)
# world: NN (NOUN)
# 's: POS (PART)
# top: JJ (ADJ)
# mobile: JJ (ADJ)
# phone: NN (NOUN)
# maker: NN (NOUN)
# ,: , (PUNCT)
# is: VBZ (AUX)
# appealing: VBG (VERB)
# the: DT (DET)
# ruling: NN (NOUN)
# .: . (PUNCT)
#
# : _SP (SPACE)
#
# Named Entities, Phrases, and Concepts:
# Samsung: ORG
#
#
# Original Sentence 6: A similar case in the UK found in Samsung's favour and ordered Apple to publish an apology making clear that the South Korean firm had not copied its iPad when designing its own devices.
# ------------
#
#
# Tokens and their POS tags (tag_):
# A: DT (DET)
# similar: JJ (ADJ)
# case: NN (NOUN)
# in: IN (ADP)
# the: DT (DET)
# UK: NNP (PROPN)
# found: VBD (VERB)
# in: IN (ADP)
# Samsung: NNP (PROPN)
# 's: POS (PART)
# favour: NN (NOUN)
# and: CC (CCONJ)
# ordered: VBD (VERB)
# Apple: NNP (PROPN)
# to: TO (PART)
# publish: VB (VERB)
# an: DT (DET)
# apology: NN (NOUN)
# making: NN (NOUN)
# clear: JJ (ADJ)
# that: IN (SCONJ)
# the: DT (DET)
# South: JJ (ADJ)
# Korean: JJ (ADJ)
# firm: NN (NOUN)
# had: VBD (AUX)
# not: RB (PART)
# copied: VBN (VERB)
# its: PRP$ (PRON)
# iPad: NNP (PROPN)
# when: WRB (SCONJ)
# designing: VBG (VERB)
# its: PRP$ (PRON)
# own: JJ (ADJ)
# devices: NNS (NOUN)
# .: . (PUNCT)
#
# Named Entities, Phrases, and Concepts:
# UK: GPE
# Samsung: ORG
# Apple: ORG
# South Korean: NORP
# iPad: ORG

# %% [markdown]
# small tip: You can use **sents = list(doc.sents)** to be able to use the index to access a sentence like **sents[2]** for the third sentence.

# %% [markdown]
# ## [total points: 7] Exercise 3: Comparison NLTK and spaCy
# We will now compare the output of NLTK and spaCy, i.e., in what do they differ?

# %% [markdown]
# ### [points: 3] Exercise 3a: Part of speech tagging
# Compare the output from NLTK and spaCy regarding part of speech tagging.
#
# * To compare, you probably would like to compare sentence per sentence. Describe if the sentence splitting is different for NLTK than for spaCy. If not, where do they differ?
# * After checking the sentence splitting, select a sentence for which you expect interesting results and perhaps differences. Motivate your choice.
# * Compare the output in `token.tag` from spaCy to the part of speech tagging from NLTK for each token in your selected sentence. Are there any differences? This is not a trick question; it is possible that there are no differences.

# %% [markdown]
# ### [points: 2] Exercise 3b: Named Entity Recognition (NER)
# * Describe differences between the output from NLTK and spaCy for Named Entity Recognition. Which one do you think performs better?

# %% [markdown]
# ### [points: 2] Exercise 3c: Constituency/dependency parsing
# Choose one sentence from the text and run constituency parsing using NLTK and dependency parsing using spaCy.
# * describe briefly the difference between constituency parsing and dependency parsing
# * describe differences between the output from NLTK and spaCy.

# %% [markdown]
# # End of this notebook
